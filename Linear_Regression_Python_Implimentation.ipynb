# %% [markdown]
# <a href="https://colab.research.google.com/github/SShalini24/Linear-Regression-Python-Implementation-/blob/main/Linear_Regression_Python_Implimentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **To Predict the Total Sales by using features like money spent on marketing on Individual Items.**

# %% [markdown]
# 1.TV - Amount spent on TV advertisement.
#
# 2.Radio - Amount spent on Radio advertisement.
#
# 3.Newspaper - Amount spent on Newspaper advertisement.
#
# 4.Sales - Sales of Product.

# %% [markdown]
# # **Domain Analysis**

# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Loading the Data**

# %%
data = pd.read_csv('/content/Advertising.csv')
data
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %% [markdown]
# **Display Top 5 Rows of the Dataset**

# %%
data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %% [markdown]
# **Display Last 5 Rows of the Dataset**

# %%
data.tail()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %% [markdown]
# **Checking the Shape**

# %%
data.shape
# Out:
# (200, 5)

# %% [markdown]
# **Getting the Information about the Dataset**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %% [markdown]
# **Getting the Statistical Details of the Dataset**

# %%
data.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# **Dropping the Unwanted columns**

# %%
data = data.drop(['Unnamed: 0'],axis=1)

# %%
data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %% [markdown]
# # **Exploratory Data Analysis**

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %% [markdown]
# ### **Univarient Analysis**

# %%
# Ananlysing the TV

# %%
sns.distplot(x=data.TV,kde=True)
plt.show()
# Out:
# <ipython-input-15-eaf4d0915132>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=data.TV,kde=True)

# %%
# Analyzing the Radio

# %%
sns.histplot(x=data.Radio,kde=True)
# Out:
# <Axes: xlabel='Radio', ylabel='Count'>

# %%
# Analyzing the Newspaper

# %%
sns.histplot(x=data.Newspaper,kde=True)
# Out:
# <Axes: xlabel='Newspaper', ylabel='Count'>

# %% [markdown]
# ### **Bivariate Analysis**

# %%
# Analyzing TV and Sales

# %%
sns.relplot(x='TV',y='Sales',data=data)
# The more marketing on TV is leading to more sales in the product.

# %%
plt.plot(data.TV)
plt.plot(data.Sales)

# %%
#Analyzing the Radio

# %%
sns.relplot(x='Radio',y='Sales',data=data)
# Radio advertisments are not showing much trend for the sales of product.

# %%
plt.plot(data.Radio)
plt.plot(data.Sales)

# %%
# Analyzing the Newspaper

# %%
sns.relplot(x='Newspaper',y='Sales',data=data)
# Newspaper advertisments are not showing much trend for the sales of product.

# %%
plt.plot(data.Newspaper)
plt.plot(data.Sales)

# %% [markdown]
# **Multivarient Analysis**

# %%
sns.pairplot(data)

# %% [markdown]
# ## **Data Preprocessing And Feature Engineering**

# %%
# Finding the Missing Value
data.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
# Checking the Outlier for TV
sns.boxplot(x='TV',data=data)
# Out:
# <Axes: xlabel='TV'>

# %%
# Checking the Outlier for Radio
sns.boxplot(x='Radio',data=data)
# Out:
# <Axes: xlabel='Radio'>

# %%
# Checking the Outlier for Newspaper
sns.boxplot(x='Newspaper',data=data)
# Out:
# <Axes: xlabel='Newspaper'>

# %% [markdown]
# ## **Feature Selection**

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
# Cheecking the Correlation
sns.heatmap(data.drop('Sales',axis=1).corr(),annot=True)
# Out:
# <Axes: >

# %%
data.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.782224
# Radio      0.054809  1.000000   0.354104  0.576223
# Newspaper  0.056648  0.354104   1.000000  0.228299
# Sales      0.782224  0.576223   0.228299  1.000000

# %% [markdown]
# ### **Model Creation**

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
# Independdent and Dependent Variable

# %%
x= data.drop('Sales',axis=1) # X variable contains all inputs
y = data.Sales # y contains all output

# %%
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
# Training and Testing Data Creation
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state =42)

# %%
x_train
# Out:
#         TV  Radio  Newspaper
# 79   116.0    7.7       23.1
# 197  177.0    9.3        6.4
# 38    43.1   26.7       35.1
# 24    62.3   12.6       18.3
# 122  224.0    2.4       15.6
# ..     ...    ...        ...
# 106   25.0   11.0       29.7
# 14   204.1   32.9       46.0
# 92   217.7   33.5       59.0
# 179  165.6   10.0       17.6
# 102  280.2   10.1       21.4
#
# [160 rows x 3 columns]

# %%
y_train
# Out:
# 79     11.0
# 197    12.8
# 38     10.1
# 24      9.7
# 122    11.6
#        ...
# 106     7.2
# 14     19.0
# 92     19.4
# 179    12.6
# 102    14.8
# Name: Sales, Length: 160, dtype: float64

# %%
# Model Creation

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()  # object creation
lr.fit(x_train,y_train)  # training of linear model
# Out:
# LinearRegression()

# %%
y_predict = lr.predict(x_test)

# %%
y_test
# Out:
# 95     16.9
# 15     22.4
# 30     21.4
# 158     7.3
# 128    24.7
# 115    12.6
# 69     22.3
# 170     8.4
# 174    11.5
# 45     14.9
# 66      9.5
# 182     8.7
# 165    11.9
# 78      5.3
# 186    10.3
# 177    11.7
# 56      5.5
# 152    16.6
# 82     11.3
# 68     18.9
# 124    19.7
# 16     12.5
# 148    10.9
# 93     22.2
# 65      9.3
# 60      8.1
# 84     21.7
# 67     13.4
# 125    10.6
# 132     5.7
# 9      10.6
# 18     11.3
# 55     23.7
# 75      8.7
# 150    16.1
# 104    20.7
# 135    11.6
# 137    20.8
# 164    11.9
# 76      6.9
# Name: Sales, dtype: float64

# %%
y_predict
# Out:
# array([16.4080242 , 20.88988209, 21.55384318, 10.60850256, 22.11237326,
#        13.10559172, 21.05719192,  7.46101034, 13.60634581, 15.15506967,
#         9.04831992,  6.65328312, 14.34554487,  8.90349333,  9.68959028,
#        12.16494386,  8.73628397, 16.26507258, 10.27759582, 18.83109103,
#        19.56036653, 13.25103464, 12.33620695, 21.30695132,  7.82740305,
#         5.80957448, 20.75753231, 11.98138077,  9.18349576,  8.5066991 ,
#        12.46646769, 10.00337695, 21.3876709 , 12.24966368, 18.26661538,
#        20.13766267, 14.05514005, 20.85411186, 11.0174441 ,  4.56899622])

# %%
# Model Evaluation

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
r2score = r2_score(y_test,y_predict)
r2score
# Out:
# 0.899438024100912

# %%
x_test.shape
# Out:
# (40, 3)

# %%
# calculation of adjusted r2_score
adjusted_r2 = 1-(1-0.89)*(40-3)/(40-3-1)

# %%
print(adjusted_r2)
# Out:
# 0.8869444444444444

# %%
import math
print(mean_squared_error(y_test,y_predict))
print(math.sqrt(mean_squared_error(y_test,y_predict)))
# Out:
# 3.1740973539761033
# 1.78159966153345

# %%
# calculation of mean_absolute_error
mean_absolute_error(y_test,y_predict)
# Out:
# 1.4607567168117603

# %% [markdown]
# # **Thank You**
